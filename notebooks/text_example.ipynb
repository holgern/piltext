# %%
from IPython.display import display

from piltext import FontManager, ImageDrawer, TextGrid, ImageDial, ImageSquares

# %%
f = FontManager(default_font_size=20)
# f.delete_all_fonts()
font1 = f.download_google_font("ofl", "roboto", "Roboto[wdth,wght].ttf")
font2 = f.download_google_font("ofl", "jersey10", "Jersey10-Regular.ttf")
f.default_font_name = font1
print(f.list_available_fonts())
# Out:
# ['Jersey10-Regular', 'Roboto[wdth,wght]']

# %%
print(f.get_variation_names())
# Out:
# [b'Thin', b'ExtraLight', b'Light', b'Regular', b'Medium', b'SemiBold', b'Bold', b'ExtraBold', b'Black', b'Condensed Thin', b'Condensed ExtraLight', b'Condensed Light', b'Condensed Regular', b'Condensed Medium', b'Condensed SemiBold', b'Condensed Bold', b'Condensed ExtraBold', b'Condensed Black']

# %%
image = ImageDrawer(100, 100, f)
xy = (0, 0)
w, h, font_size = image.draw_text("Test", xy, font_variation="Bold")
xy = (xy[0], xy[1] + h)
w, h, font_size = image.draw_text("Test", xy)
xy = (xy[0] + w, xy[1])
w, h, font_size = image.draw_text("Test", xy)
xy = (xy[0], xy[1] + h)
w, h, font_size = image.draw_text("Test", xy, font_name=font2, fill=128)
xy = (0, xy[1] + h)
w, h, font_size = image.draw_text(
    "Test", xy, end=(100, 100), font_variation="Condensed Medium"
)
print(f"w: {w}, h:{h}, font_size: {font_size}")

image.finalize(inverted=False)
display(image.get_image())
# Out:
# w: 82, h:45, font_size: 48
# <PIL.Image.Image image mode=L size=100x100>

# %%
image = ImageDrawer(480, 280, f)
xy = (5, 3)
w, h, font_size = image.draw_text(
    "Long Text 1", xy, end=(480, (280 - 15) / 3), anchor="lt"
)
xy = (5, int(h * 0.85))
w, h, font_size = image.draw_text(
    "Long Text 2", xy, end=(480, xy[1] * 1.5), anchor="lt"
)
xy = (5, xy[1] + h)
w, h, font_size = image.draw_text(
    "Long Text 3", xy, font_size=font_size, font_variation="Thin", anchor="lt"
)
xy = (5, xy[1] + h)
w, h, font_size = image.draw_text("Long Text 3", xy, font_size=font_size, anchor="lt")
w, h, font_size = image.draw_text(
    "Long Text 4", (480 - 5, 280 - 5), end=(5, 5), anchor="rs"
)

image.finalize(inverted=False)
display(image.get_image())
# Out:
# <PIL.Image.Image image mode=L size=480x280>

# %%
f.list_available_fonts()
# Out:
# ['Jersey10-Regular', 'Roboto[wdth,wght]']

# %%
image = ImageDrawer(480, 280, f)

grid = TextGrid(7, 4, image, margin_x=2, margin_y=2)
grid.print_grid()
merge_list = [
    ((0, 0), (0, 3)),
    ((1, 0), (2, 1)),
    ((1, 2), (2, 3)),
    ((3, 0), (6, 3)),
]
grid.merge_bulk(merge_list)
grid.print_grid()
# Out:
# Grid Layout:
#   0 1 2 3
# ---------
# 0|. . . .
# 1|. . . .
# 2|. . . .
# 3|. . . .
# 4|. . . .
# 5|. . . .
# 6|. . . .
#
# Grid Layout:
#   0 1 2 3
# ---------
# 0|0 . . 0
# 1|1 . 2 .
# 2|. 1 . 2
# 3|3 . . .
# 4|. . . .
# 5|. . . .
# 6|. . . 3

# %%
grid.get_merged_cells()
# Out:
# {(0, 0): ((0, 0), (0, 3)),
#  (1, 0): ((1, 0), (2, 1)),
#  (1, 2): ((1, 2), (2, 3)),
#  (3, 0): ((3, 0), (6, 3))}

# %%
image.initialize()
grid.set_text(0, "Test1", font_name=font2)
grid.set_text(1, "Test2")
grid.set_text(2, "Test3")
grid.set_text(3, "Test4", anchor="lt")
image.finalize(inverted=False)
display(image.get_image())
# Out:
# <PIL.Image.Image image mode=L size=480x280>

# %%
image.initialize()
text_list = [
    {"start": 0, "text": "Test1", "font_name": font2},
    {"start": 1, "text": "Test2"},
    {"start": 2, "text": "Test3"},
    {"start": 3, "text": "Test4", "anchor": "lt", "fill": 128},
]
grid.set_text_list(text_list)
image.finalize(inverted=False)
display(image.get_image())
# Out:
# <PIL.Image.Image image mode=L size=480x280>

# %%
img = image.get_image().copy()
image.initialize()
grid.set_text(0, "Test1", font_name=font2)
grid.set_text(1, "Test2")
grid.set_text(2, "Test3")
grid.draw_grid_borders()
grid.paste_image(3, img, anchor="ls")
image.finalize(inverted=False)
display(image.get_image())
# Out:
# <PIL.Image.Image image mode=L size=480x280>

# %%
img = image.get_image().copy()
image.initialize()
print(grid.grid2pixel[(0, 0)])
print(grid.grid2pixel[(1, 0)])
print(grid.grid2pixel[(1, 2)])
print(grid.grid2pixel[(3, 0)])
grid.print_grid()
# Out:
# [2, 2, 118, 38]
# [2, 42, 118, 78]
# [242, 42, 358, 78]
# [2, 122, 118, 158]
#
# Grid Layout:
#   0 1 2 3
# ---------
# 0|0 . . 0
# 1|1 . 2 .
# 2|. 1 . 2
# 3|3 . . .
# 4|. . . .
# 5|. . . .
# 6|. . . 3

# %%
grid.merge((0, 0), (0, 4))
print(grid.grid2pixel[(0, 0)])
# Out:
# [2, 2, 118, 38]

# %%
grid.set_text(0, "Welcome to the Dashboard", font_name=font2)
grid.set_text(1, "Test1", font_name=font2)
grid.set_text(2, "Test2")
grid.set_text(3, "Test3")
grid.draw_grid_borders()
image.finalize(inverted=False)
display(image.get_image())
# Out:
# <PIL.Image.Image image mode=L size=480x280>

# %%
print(grid.grid2pixel[(0, 0)])
grid.print_grid()
# Out:
# [2, 2, 118, 38]
#
# Grid Layout:
#   0 1 2 3
# ---------
# 0|0 . . .
# 1|1 . 2 .
# 2|. 1 . 2
# 3|3 . . .
# 4|. . . .
# 5|. . . .
# 6|. . . 3

# %%
image = ImageDrawer(480, 280, f)

grid = TextGrid(7, 4, image, margin_x=2, margin_y=2)
merge_list = [
    ((0, 0), (0, 3)),
    ((1, 0), (2, 1)),
    ((1, 2), (2, 3)),
    ((3, 0), (6, 3)),
]
grid.merge_bulk(merge_list)
d0 = grid.get_dimensions(0)
d1 = grid.get_dimensions(1)
d2 = grid.get_dimensions(2)
# grid.modify_grid2pixel(0, d_y2=20)
# grid.modify_grid2pixel(1, d_y1=20)
# grid.modify_grid2pixel(2, d_y1=20)
row_h = grid.get_required_row_height_for_text(
    0, "Welcome to the Dashboard", font_name=font2
)
print(f"delta_y = {row_h}, d0 height {d0['height']}")
delta_y = row_h - d0["height"]

grid.modify_row_height(0, delta_y2=delta_y)
grid.modify_row_height(1, delta_y1=delta_y)
grid.get_dimensions(0)
grid.get_dimensions(1)
grid.get_dimensions(2)
grid.draw_grid_borders()
grid.set_text(0, "Welcome to the Dashboard", font_name=font2)
grid.set_text(1, "Test1", font_name=font2)
grid.set_text(2, "Test2")
grid.set_text(3, "Test3")
image.finalize(inverted=False)
display(image.get_image())
# Out:
# delta_y = 40, d0 height 36
# <PIL.Image.Image image mode=L size=480x280>

# %%
image = ImageDrawer(480, 280, f)
image.initialize()
dial = ImageDial(0.4, f, font_name=None, show_needle=False, show_ticks=False, show_value=False, start_angle=-180, end_angle=180, track_color="white", size=200)
dial._draw_dial(image)
dial2 = ImageDial(0.8, f, font_name=None, show_needle=False, show_ticks=False, show_value=False, start_angle=-180, end_angle=180, track_color="white", size=200, radius=60)
dial2._draw_dial(image)
dial2 = ImageDial(0.2, f, font_name=None, show_needle=False, show_ticks=False, show_value=False, start_angle=-180, end_angle=180, track_color="white", size=200, radius=30)
dial2._draw_dial(image)
image.finalize(inverted=False)
display(image.get_image())
# Out:
# <PIL.Image.Image image mode=L size=480x280>

# %%
image = ImageDrawer(480, 280, f)
image.initialize()
squares = ImageSquares(0.6, f, max_squares=4, size=280, bg_color="grey", fg_color="black", empty_color="white", border_color="grey", columns=4, show_partial=True, gap=0)
squares._draw_squares(image)
image.finalize(inverted=False)
display(image.get_image())
# Out:
# <PIL.Image.Image image mode=L size=480x280>
